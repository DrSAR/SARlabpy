# %%
import sarpy

# %%
import sarpy
xx = sarpy.Experiment('HerS18Bs06')
yy=xx.studies[0].scans[3]
yy.pdata[0].data.shape
# Out:
# (64, 128, 8)

# %%
import pylab
pylab.imshow(yy.pdata[0].data[:,:,4])

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import numpy as np

# %%
x=np.random.random(size=1000)*100
y=np.random.random(size=1000)*100
radii = np.random.random(size=1000)*1.5

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3f207f03-8b7a-4a37-a3ec-2a0395cf05ba">Loading BokehJS ...</span>
#     </div>

# %%
p=figure()
p.circle(x,y,radius=radii, fill_alpha=0.6, line_color=None)
show(p)
# Out:
#     <div class="plotdiv" id="7b144b8f-c9a4-46e1-8d13-f65c24a3f166"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
from IPython.display import Image

# %%
import ipywidgets 
from IPython.display import display, clear_output

import plotly.plotly as py
from plotly.graph_objs import *
import plotly
from plotly.widgets import GraphWidget

import pandas as pd
# Out:
# /Users/stefan/anaconda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning:
#
# The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#
# /Users/stefan/anaconda/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning:
#
# IPython.utils.traitlets has moved to a top-level traitlets package.

# %%
#df = pd.read_csv('https://raw.githubusercontent.com/plotly/widgets/master/ipython-examples/311_150k.csv', infer_datetime_format=True)
df = pd.read_csv('/Users/stefan/Downloads/311_150k.csv', infer_datetime_format=True)

df = df
df.head()
# Out:
# /Users/stefan/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning:
#
# Columns (8,39,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#    Unique Key            Created Date             Closed Date Agency  \
# 0    29300358  11/16/2014 11:46:00 PM  11/16/2014 11:46:00 PM   DSNY
# 1    29299837  11/16/2014 02:24:35 AM  11/16/2014 02:24:35 AM    DOB
# 2    29297857  11/16/2014 02:17:12 AM  11/16/2014 02:50:48 AM   NYPD
# 3    29294647  11/16/2014 02:15:13 AM                     NaN   NYPD
# 4    29300211  11/16/2014 02:14:01 AM                     NaN   NYPD
#
#                        Agency Name           Complaint Type  \
# 0                BCC - Queens East        Derelict Vehicles
# 1          Department of Buildings             Building/Use
# 2  New York City Police Department          Illegal Parking
# 3  New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
df['Complaint Type'].value_counts()
# Out:
# HEAT/HOT WATER                          32202
# Street Light Condition                   7558
# Blocked Driveway                         6997
# UNSANITARY CONDITION                     6174
# PAINT/PLASTER                            5388
# Illegal Parking                          5381
# Street Condition                         4847
# Noise                                    4615
# PLUMBING                                 4284
# Water System                             3323
# Noise - Commercial                       3206
# DOOR/WINDOW                              3194
# Traffic Signal Condition                 2766
# WATER LEAK                               2501
# Dirty Conditions                         2283
# ELECTRIC                                 2205
# Sanitation Condition                     2195
# DOF Literature Request                   2183
# Broken Muni Meter                        2159
# FLOORING/STAIRS                          2129
# ...

# %%
c = df['Complaint Type'].value_counts()
url = py.plot([Bar(x=c.index, y=c.values)], filename='311 most common complaints', auto_open=False)
plotly.tools.embed(url)
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~DrSAR/0 or inside your plot.ly account where it is named '311 most common complaints'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~DrSAR/0.embed" height="525" width="100%"></iframe>

# %%
import plotly.plotly as py
from plotly.graph_objs import *
import plotly.tools as tls

import json
import numpy as np
import math
from IPython.display import display

# %%
import sarpy
scn_to_analyse = sarpy.Scan('CestS1Cs04.xY1/10')
scn_to_analyse.pdata[0].data.shape
# Out:
# (64, 64, 80)

# %%
trace=Heatmap(x=np.arange(64), y=np.arange(64), z=scn_to_analyse.pdata[0].data[:,:,0])

# %%
#fig = Figure(data=[trace])
#py.plot(fig)

# %%
from plotly.widgets import GraphWidget

# %%
contour_plot = GraphWidget('https://plot.ly/~bronsolo/63')
line_plot = GraphWidget('https://plot.ly/~chris/2150')

display(contour_plot)
display(line_plot)

# %%
image_plot = GraphWidget('http://plot.ly/~DrSAR/2')
display(image_plot)
